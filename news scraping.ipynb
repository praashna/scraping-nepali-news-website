# %% [markdown]
# # web scraping

# %%
! pip install beautifulsoup4

# %%
! pip install requests

# %% [markdown]
# # IMPORTING LIBARIES

# %%
from bs4 import BeautifulSoup
import requests
import re

# %%
url = BeautifulSoup("https://ekantipur.com/news/2022/11/30/166980468019054865.html",'html.parser')
raw_code = requests.get(url)
raw_code
# Out:
# C:\Users\User\anaconda3\lib\site-packages\bs4\__init__.py:404: MarkupResemblesLocatorWarning: The input looks more like a URL than markup. You may want to use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# <Response [200]>

# %%
raw_code.text
# Out:
# '<!DOCTYPE html><html lang="ne"><head><meta http-equiv="Content-Type" content="text/html; charset=utf-8" /><meta name="description" content="जिल्ला प्रशासन कार्यालय काठमाडौंले सोमबार काठमाडौं नगर प्रहरीमाथि सांघातिक आक्रमण गर्ने ४ जनालाई पक्राउ गरी अनुसन्धान प्रक्रिया अगाडि बढाउन निर्देशन दिएको छ ।"><meta name="keyword" content="जिल्ला ,प्रशासन ,कार्यालय ,काठमाडौं ,सोमबार ,काठमाडौं ,नगर ,प्रहरी ,सांघातिक ,आक्रमण ,४ ,जना ,पक्राउ ,अनुसन्धान ,प्रक्रिया ,अगाडि ,बढाउन ,निर्देशन "><meta name="web_author" content="कान्तिपुर संवाददाता"> <meta name="robots" content=""> <meta name="language" content=""><meta name="reply-to" content=""><meta name="revisit-after" content=""><meta property="og:image" content="https://assets-cdn.kantipurdaily.com/uploads/source/news/kantipur/2022/miscellaneous/sukumbasi-30112022093754.jpg"><meta property="og:title" content="काठमाडौं महानगर प्रहरीमाथि आक्रमण गर्ने ४ जनालाई पक्राउ गर्न प्रशासनको निर्देशन"><meta property="og:type" content="article"/><meta name="viewp
# ...

# %%
raw_code = BeautifulSoup(raw_code.text,"lxml")
raw_code
# Out:
# <!DOCTYPE html>
# ...

# %%
tags = raw_code.find_all('p') #find_all is the function to return all 
tags
# Out:
# [<p>नतिजा हेर्नको लागि लगइन गर्नुहोस् ।</p>,
#  <p class="text"><span>तपाईको प्रतिक्रिया समीक्षामा भएकोले प्रकाशित भएको छैन । </span></p>,
#  <p>काठमाडौँ — जिल्ला प्रशासन कार्यालय काठमाडौंले सोमबार काठमाडौं नगर प्रहरीमाथि सांघातिक आक्रमण गर्ने ४ जनालाई पक्राउ गरी अनुसन्धान प्रक्रिया अगाडि बढाउन निर्देशन दिएको छ ।</p>,
#  <p>सोमबार थापाथलीस्थित सुकुम्बासी बस्ती खाली गराउन भन्दै गएको महानगरको टोलीमाथि सांघातिक आक्रमण भएको भन्दै काठमाडौं महानगरपालिकाले काठमाडौं प्रहरी परिसर टेकुमा उजुरी गरेको थियो ।</p>,
#  <p>साथै उक्त प्रकरणबारे महानगरले जिल्ला प्रशासन कार्यालयलाई समेत जानकारी गराएको थियो । बुधबार जिल्ला प्रशासन कार्यालयले नगर प्रहरीमाथि आक्रमण गरेको आरोपमा नारायण परिश्रमी, हुकुमबहादुर लामा, दीपकजंग कुँवर र राजु तामाङलाई पक्राउ गरी अनुसन्धान अघि बढाउन प्रहरीलाई निर्देशन दिएको हो ।</p>,
# ...

# %%
raw_data = []
for tag in tags:
    raw_data.append(tag.text)

raw_data
# Out:
# ['नतिजा हेर्नको लागि लगइन गर्नुहोस् ।',
#  'तपाईको प्रतिक्रिया समीक्षामा भएकोले प्रकाशित भएको छैन\xa0। ',
#  'काठमाडौँ — जिल्ला प्रशासन कार्यालय काठमाडौंले सोमबार काठमाडौं नगर प्रहरीमाथि सांघातिक आक्रमण गर्ने ४ जनालाई पक्राउ गरी अनुसन्धान प्रक्रिया अगाडि बढाउन निर्देशन दिएको छ\xa0।',
#  'सोमबार थापाथलीस्थित सुकुम्बासी बस्ती खाली गराउन भन्दै गएको महानगरको टोलीमाथि सांघातिक आक्रमण भएको भन्दै काठमाडौं महानगरपालिकाले काठमाडौं प्रहरी परिसर टेकुमा उजुरी गरेको थियो\xa0।',
#  'साथै उक्त प्रकरणबारे महानगरले जिल्ला प्रशासन कार्यालयलाई समेत जानकारी गराएको थियो\xa0। बुधबार जिल्ला प्रशासन कार्यालयले नगर प्रहरीमाथि आक्रमण गरेको आरोपमा नारायण परिश्रमी, हुकुमबहादुर लामा, दीपकजंग कुँवर र राजु तामाङलाई पक्राउ गरी अनुसन्धान अघि बढाउन प्रहरीलाई निर्देशन दिएको हो\xa0।',
# ...

# %%
# raw_data = re.sub(r"[\u202f]","",raw_data)
# raw_data

# %%
# for i in raw

# raw_data = raw_data.replace('\xa0','')
# raw_data

# %%
# new_data = []
# for i in raw_data:
#     new_data.append(i.replace('\xa0',''))
#     new_data.append(i.replace('\u202f',''))
    
    
# new_data

# %%
# new_data = new_data.replace("")

# %%
# ' '.join(raw_data)

# %%
# raw_data = re.sub(r"[\u202f]","",raw_data)
# raw_data

# %%
# raw_data = raw_data.replace('\xa0','')

# %%
print(type(raw_data))
# Out:
# <class 'list'>

# %%
string = ''
for x in raw_data:
    string += ''+x
    
print(string)
# Out:
# नतिजा हेर्नको लागि लगइन गर्नुहोस् ।तपाईको प्रतिक्रिया समीक्षामा भएकोले प्रकाशित भएको छैन । काठमाडौँ — जिल्ला प्रशासन कार्यालय काठमाडौंले सोमबार काठमाडौं नगर प्रहरीमाथि सांघातिक आक्रमण गर्ने ४ जनालाई पक्राउ गरी अनुसन्धान प्रक्रिया अगाडि बढाउन निर्देशन दिएको छ ।सोमबार थापाथलीस्थित सुकुम्बासी बस्ती खाली गराउन भन्दै गएको महानगरको टोलीमाथि सांघातिक आक्रमण भएको भन्दै काठमाडौं महानगरपालिकाले काठमाडौं प्रहरी परिसर टेकुमा उजुरी गरेको थियो ।साथै उक्त प्रकरणबारे महानगरले जिल्ला प्रशासन कार्यालयलाई समेत जानकारी गराएको थियो । बुधबार जिल्ला प्रशासन कार्यालयले नगर प्रहरीमाथि आक्रमण गरेको आरोपमा नारायण परिश्रमी, हुकुमबहादुर लामा, दीपकजंग कुँवर र राजु तामाङलाई पक्राउ गरी अनुसन्धान अघि बढाउन प्रहरीलाई निर्देशन दिएको हो ।उनीहरूमाथि नगर प्रहरी प्रमुख राजु पाण्डे, नगर प्रहरी जवान शर्मिला बोगटीलगायत १८ जनालाई आपराधिक बल तथा हातहतियार प्रयोग गरी बन्धक बनाई सांघातिक आक्रमण गरी घाइते बनाएको आरोपमा अनुसन्धान अघि बढाइने प्रहरी परिसरले जनाएको छ । उनीहरूमाथि मुलुकी अपराध संहिता २०७४ को दफा ८५, दफा १९६ र दफा २१२ 
# ...

# %%
import nltk
import re
import heapq
import numpy as np

# %%
dataset = nltk.sent_tokenize(string)
dataset
# Out:
# ['नतिजा हेर्नको लागि लगइन गर्नुहोस् ।तपाईको प्रतिक्रिया समीक्षामा भएकोले प्रकाशित भएको छैन\xa0। काठमाडौँ — जिल्ला प्रशासन कार्यालय काठमाडौंले सोमबार काठमाडौं नगर प्रहरीमाथि सांघातिक आक्रमण गर्ने ४ जनालाई पक्राउ गरी अनुसन्धान प्रक्रिया अगाडि बढाउन निर्देशन दिएको छ\xa0।सोमबार थापाथलीस्थित सुकुम्बासी बस्ती खाली गराउन भन्दै गएको महानगरको टोलीमाथि सांघातिक आक्रमण भएको भन्दै काठमाडौं महानगरपालिकाले काठमाडौं प्रहरी परिसर टेकुमा उजुरी गरेको थियो\xa0।साथै उक्त प्रकरणबारे महानगरले जिल्ला प्रशासन कार्यालयलाई समेत जानकारी गराएको थियो\xa0। बुधबार जिल्ला प्रशासन कार्यालयले नगर प्रहरीमाथि आक्रमण गरेको आरोपमा नारायण परिश्रमी, हुकुमबहादुर लामा, दीपकजंग कुँवर र राजु तामाङलाई पक्राउ गरी अनुसन्धान अघि बढाउन प्रहरीलाई निर्देशन दिएको हो\xa0।उनीहरूमाथि नगर प्रहरी प्रमुख राजु पाण्डे, नगर प्रहरी जवान शर्मिला बोगटीलगायत १८ जनालाई आपराधिक बल तथा हातहतियार प्रयोग गरी बन्धक बनाई सांघातिक आक्रमण गरी घाइते बनाएको आरोपमा अनुसन्धान अघि बढाइने प्रहरी परिसरले जनाएको छ\xa0। उनीहरूमाथि मुलुकी अपराध संहिता २०७४ को दफा ८५
# ...
